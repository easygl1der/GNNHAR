# %% [markdown]
# # BrowserOS Colab Smoke Test
#
# This notebook verifies that a pre-generated notebook can be opened from GitHub in Google Colab and run on a Colab runtime.

# %%
import os, platform, sys
print('browseros colab smoke test: ok')
print('python:', sys.version.split()[0])
print('platform:', platform.platform())
print('cwd:', os.getcwd())
